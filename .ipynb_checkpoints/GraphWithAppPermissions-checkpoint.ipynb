# %% [markdown]
# # Python on Microsoft Graph with App Permissions
#
# ## by Fabian Williams - Sr.Program Manager on the Microsoft Graph CPx team
#
# ### Contact Me
# Twitter: @fabianwilliams
# Email: fabian.williams@microsoft.com

# %% [markdown]
# ## Import Libraries

# %%
import msal
import jwt
import json 
import requests 
import pandas as pd 
from datetime import datetime
from configparser import ConfigParser

# %% [markdown]
# ## Set Variables / Constants

# %%
accessToken = None 
requestHeaders = None 
tokenExpiry = None 
queryResults = None 
graphURI = 'https://graph.microsoft.com'

# %% [markdown]
# ## Read in the Config File

# %%
config = ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %% [markdown]
# ## Function to Authenticate against Graph

# %%
def msgraph_auth():
    global accessToken
    global requestHeaders
    global tokenExpiry
    tenantID = config['apppermissiononly'] ['tenantID']
    authority = config['apppermissiononly'] ['authority'] + tenantID
    clientID = config['apppermissiononly'] ['clientID']
    clientSecret = config['apppermissiononly'] ['clientSecret']
    scope = ['https://graph.microsoft.com/.default']

    app = msal.ConfidentialClientApplication(clientID, authority=authority, client_credential = clientSecret)

    try:
        accessToken = app.acquire_token_silent(scope, account=None)
        if not accessToken:
            try:
                accessToken = app.acquire_token_for_client(scopes=scope)
                if accessToken['access_token']:
                    print('New access token retreived....')
                    requestHeaders = {'Authorization': 'Bearer ' + accessToken['access_token']}
                else:
                    print('Error Caught: Check the Config File to make sure tenantID, clientID and clientSecret is correct')
            except:
                pass 
        else:
            print('Token retreived from MSAL Cache....')
        return
    except Exception as err:
        print(err)

# %% [markdown]
# ## Function to Call the Graph Resource and return JSON

# %%
def msgraph_request(resource,requestHeaders):
    # Request
    results = requests.get(resource, headers=requestHeaders).json()
    return results

# %% [markdown]
# ## Call the Authenticate Function

# %%
msgraph_auth()
# Out:
# New access token retreived....

# %% [markdown]
# ## Call the Graph EndPoint for Users

# %%
queryResults = msgraph_request(graphURI +'/v1.0/users',requestHeaders)

# %% [markdown]
# ## Send the Results to a Pandas Dataframe

# %%
    df = pd.read_json(json.dumps(queryResults['value']))
    # set ID column as index in Pandas Dataframe
    df = df.set_index('id')

# %% [markdown]
# ## Print the Pandas Dataframe with the Graph Users from the Tenant

# %%
df
# Out:
#                                          businessPhones        displayName  \
# id
# eb14fa25-43e5-45f8-973d-7ea79a346db6  [+1 425 555 0109]        Adele Vance
# 9917978c-e41e-47a0-aaf8-db4844ab9074  [+1 858 555 0110]        Alex Wilber
# fa2480cc-103b-4b53-8ba6-da9720c81c2d  [+1 205 555 0108]    Diego Siciliani
# 28031fbd-75af-4b61-8afd-347aac675901       [4251001000]    Fabian Williams
# 54b54aaf-e4a3-4367-939e-3a899a686b9d  [+1 309 555 0104]       Grady Archie
# 40c7b8f5-1552-4609-bfe2-1bd4dd4443c6  [+1 954 555 0118]  Henrietta Mueller
# a877ec3b-089f-46bb-9e67-ef696e542891  [+1 918 555 0101]      Isaiah Langer
# 8418b5a1-622d-470b-bf9f-964c2325641e  [+1 502 555 0102]     Johanna Lorenz
# ad5a9b47-674e-45d6-bfcf-96d3ab1c7235  [+1 980 555 0101]       Joni Sherman
# 40c847a3-9484-4f5e-ac4b-c93e256224cf  [+1 913 555 0101]             Lee Gu
# 7b4cc045-8f17-4920-b892-57681814c7c9  [+1 918 555 0107]     Lidia Holloway
# 528a6f27-4ab7-4c13-b4a6-1862a39904d6  [+1 918 555 0104]      Lynne Robbins
# c5a81ac5-4bc0-4090-aa11-3ec7e837ccca  [+1 412 555 0109]        Megan Bowen
# ee2f724c-8930-4bc1-a3b1-497be1956131  [+1 858 555 0109]      Miriam Graham
# 9d4f4547-f703-474e-b467-44dd7d82b81b  [+1 206 555 0105]       Nestor Wilke
# 15beb2ef-1b5d-4524-b97e-fe61444d7d47  [+1 502 555 0144]    Patti Fernandez
# 0114f589-1751-4379-9ea8-f4f70051f096    [+20 255501070]      Pradeep Gupta
#
#                                       givenName             jobTitle  \
# id
# eb14fa25-43e5-45f8-973d-7ea79a346db6      Adele       Retail Manager
# 9917978c-e41e-47a0-aaf8-db4844ab9074       Alex  Marketing Assistant
# fa2480cc-103b-4b53-8ba6-da9720c81c2d      Diego           HR Manager
# 28031fbd-75af-4b61-8afd-347aac675901     Fabian                 None
# 54b54aaf-e4a3-4367-939e-3a899a686b9d      Grady             Designer
# 40c7b8f5-1552-4609-bfe2-1bd4dd4443c6  Henrietta            Developer
# a877ec3b-089f-46bb-9e67-ef696e542891     Isaiah            Sales Rep
# 8418b5a1-622d-470b-bf9f-964c2325641e    Johanna      Senior Engineer
# ad5a9b47-674e-45d6-bfcf-96d3ab1c7235       Joni            Paralegal
# 40c847a3-9484-4f5e-ac4b-c93e256224cf        Lee             Director
# 7b4cc045-8f17-4920-b892-57681814c7c9      Lidia      Product Manager
# 528a6f27-4ab7-4c13-b4a6-1862a39904d6      Lynne              Planner
# c5a81ac5-4bc0-4090-aa11-3ec7e837ccca      Megan    Marketing Manager
# ee2f724c-8930-4bc1-a3b1-497be1956131     Miriam             Director
# 9d4f4547-f703-474e-b467-44dd7d82b81b     Nestor             Director
# 15beb2ef-1b5d-4524-b97e-fe61444d7d47      Patti            President
# 0114f589-1751-4379-9ea8-f4f70051f096    Pradeep           Accountant
#
#                                                                     mail  \
# id
# eb14fa25-43e5-45f8-973d-7ea79a346db6      AdeleV@fabster.onmicrosoft.com
# 9917978c-e41e-47a0-aaf8-db4844ab9074       AlexW@fabster.onmicrosoft.com
# fa2480cc-103b-4b53-8ba6-da9720c81c2d      DiegoS@fabster.onmicrosoft.com
# 28031fbd-75af-4b61-8afd-347aac675901      fabian@fabster.onmicrosoft.com
# 54b54aaf-e4a3-4367-939e-3a899a686b9d      GradyA@fabster.onmicrosoft.com
# 40c7b8f5-1552-4609-bfe2-1bd4dd4443c6  HenriettaM@fabster.onmicrosoft.com
# a877ec3b-089f-46bb-9e67-ef696e542891     IsaiahL@fabster.onmicrosoft.com
# 8418b5a1-622d-470b-bf9f-964c2325641e    JohannaL@fabster.onmicrosoft.com
# ad5a9b47-674e-45d6-bfcf-96d3ab1c7235       JoniS@fabster.onmicrosoft.com
# 40c847a3-9484-4f5e-ac4b-c93e256224cf        LeeG@fabster.onmicrosoft.com
# 7b4cc045-8f17-4920-b892-57681814c7c9      LidiaH@fabster.onmicrosoft.com
# 528a6f27-4ab7-4c13-b4a6-1862a39904d6      LynneR@fabster.onmicrosoft.com
# c5a81ac5-4bc0-4090-aa11-3ec7e837ccca      MeganB@fabster.onmicrosoft.com
# ee2f724c-8930-4bc1-a3b1-497be1956131     MiriamG@fabster.onmicrosoft.com
# 9d4f4547-f703-474e-b467-44dd7d82b81b     NestorW@fabster.onmicrosoft.com
# 15beb2ef-1b5d-4524-b97e-fe61444d7d47      PattiF@fabster.onmicrosoft.com
# 0114f589-1751-4379-9ea8-f4f70051f096    PradeepG@fabster.onmicrosoft.com
#
#                                       mobilePhone officeLocation  \
# id
# eb14fa25-43e5-45f8-973d-7ea79a346db6          NaN        18/2111
# 9917978c-e41e-47a0-aaf8-db4844ab9074          NaN       131/1104
# fa2480cc-103b-4b53-8ba6-da9720c81c2d          NaN        14/1108
# 28031fbd-75af-4b61-8afd-347aac675901          NaN           None
# 54b54aaf-e4a3-4367-939e-3a899a686b9d          NaN        19/2109
# 40c7b8f5-1552-4609-bfe2-1bd4dd4443c6          NaN        18/1106
# a877ec3b-089f-46bb-9e67-ef696e542891          NaN        20/1101
# 8418b5a1-622d-470b-bf9f-964c2325641e          NaN        23/2102
# ad5a9b47-674e-45d6-bfcf-96d3ab1c7235          NaN        20/1109
# 40c847a3-9484-4f5e-ac4b-c93e256224cf          NaN        23/3101
# 7b4cc045-8f17-4920-b892-57681814c7c9          NaN        20/2107
# 528a6f27-4ab7-4c13-b4a6-1862a39904d6          NaN        20/1104
# c5a81ac5-4bc0-4090-aa11-3ec7e837ccca          NaN        12/1110
# ee2f724c-8930-4bc1-a3b1-497be1956131          NaN       131/2103
# 9d4f4547-f703-474e-b467-44dd7d82b81b          NaN        36/2121
# 15beb2ef-1b5d-4524-b97e-fe61444d7d47          NaN        15/1102
# 0114f589-1751-4379-9ea8-f4f70051f096          NaN        98/2202
#
#                                      preferredLanguage    surname  \
# id
# eb14fa25-43e5-45f8-973d-7ea79a346db6             en-US      Vance
# 9917978c-e41e-47a0-aaf8-db4844ab9074             en-US     Wilber
# fa2480cc-103b-4b53-8ba6-da9720c81c2d             en-US  Siciliani
# 28031fbd-75af-4b61-8afd-347aac675901             en-US   Williams
# 54b54aaf-e4a3-4367-939e-3a899a686b9d             en-US     Archie
# 40c7b8f5-1552-4609-bfe2-1bd4dd4443c6             en-US    Mueller
# a877ec3b-089f-46bb-9e67-ef696e542891             en-US     Langer
# 8418b5a1-622d-470b-bf9f-964c2325641e             en-US     Lorenz
# ad5a9b47-674e-45d6-bfcf-96d3ab1c7235             en-US    Sherman
# 40c847a3-9484-4f5e-ac4b-c93e256224cf             en-US         Gu
# 7b4cc045-8f17-4920-b892-57681814c7c9             en-US   Holloway
# 528a6f27-4ab7-4c13-b4a6-1862a39904d6             en-US    Robbins
# c5a81ac5-4bc0-4090-aa11-3ec7e837ccca             en-US      Bowen
# ee2f724c-8930-4bc1-a3b1-497be1956131             en-US     Graham
# 9d4f4547-f703-474e-b467-44dd7d82b81b             en-US      Wilke
# 15beb2ef-1b5d-4524-b97e-fe61444d7d47             en-US  Fernandez
# 0114f589-1751-4379-9ea8-f4f70051f096             en-US      Gupta
#
#                                                        userPrincipalName
# id
# eb14fa25-43e5-45f8-973d-7ea79a346db6      AdeleV@fabster.onmicrosoft.com
# 9917978c-e41e-47a0-aaf8-db4844ab9074       AlexW@fabster.onmicrosoft.com
# fa2480cc-103b-4b53-8ba6-da9720c81c2d      DiegoS@fabster.onmicrosoft.com
# 28031fbd-75af-4b61-8afd-347aac675901      fabian@fabster.onmicrosoft.com
# 54b54aaf-e4a3-4367-939e-3a899a686b9d      GradyA@fabster.onmicrosoft.com
# 40c7b8f5-1552-4609-bfe2-1bd4dd4443c6  HenriettaM@fabster.onmicrosoft.com
# a877ec3b-089f-46bb-9e67-ef696e542891     IsaiahL@fabster.onmicrosoft.com
# 8418b5a1-622d-470b-bf9f-964c2325641e    JohannaL@fabster.onmicrosoft.com
# ad5a9b47-674e-45d6-bfcf-96d3ab1c7235       JoniS@fabster.onmicrosoft.com
# 40c847a3-9484-4f5e-ac4b-c93e256224cf        LeeG@fabster.onmicrosoft.com
# 7b4cc045-8f17-4920-b892-57681814c7c9      LidiaH@fabster.onmicrosoft.com
# 528a6f27-4ab7-4c13-b4a6-1862a39904d6      LynneR@fabster.onmicrosoft.com
# c5a81ac5-4bc0-4090-aa11-3ec7e837ccca      MeganB@fabster.onmicrosoft.com
# ee2f724c-8930-4bc1-a3b1-497be1956131     MiriamG@fabster.onmicrosoft.com
# 9d4f4547-f703-474e-b467-44dd7d82b81b     NestorW@fabster.onmicrosoft.com
# 15beb2ef-1b5d-4524-b97e-fe61444d7d47      PattiF@fabster.onmicrosoft.com
# 0114f589-1751-4379-9ea8-f4f70051f096    PradeepG@fabster.onmicrosoft.com
